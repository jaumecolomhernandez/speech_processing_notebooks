# %% [markdown]
# # Speaker verification
# Implementation of a basic speaker classification system. It uses GMMS to model the speakers voice from MFCCs.

# %%
#IMPORTS
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
plt.style.use('ggplot')
rcParams['figure.figsize'] = 16, 8

from sklearn.mixture import GaussianMixture as GMM
from sklearn.decomposition import PCA
from sklearn import metrics

import sys
import os
import glob
import random

import librosa
import librosa.display

# %%
#DEFINICIO VARIABLES 
base_path = '/home/jc/speech_processing_notebooks'    #Carpeta practica 4
speecon_path = os.path.join(base_path,'audios','speecon')    #Carpeta Speecon
temp_path = os.path.join(base_path,'exports')    #Carpeta exports

# %% [markdown]
# ### Generic function

# %%
def mfcc(files, n_coefs=16):
    ''' Función genérica MFCC
        Función genérica para calcular los coeficientes MFCC dada
        una lista con los paths a los audios.
        Utiliza la libreria librosa para leer el
        audio y calcular los coeficientes.
        Parametros:
        - files: lista con los ficheros a computar
        - n_coefs: int numero de coeficientes para el MFCC
        Devuelve:
        - base: np.array de tamaño Nxn_coefs con los coeficientes para cada trama'''
    
    #Inicializamos un array a ceros
    base = np.zeros((1,n_coefs))
    
    for file_audio in files:
        #Lectura del audio, remuestreamos a 8000Hz
        audio, fs = librosa.core.load(file_audio, sr=8000)
        #Calculo de los coefs
        mfcc_raw = librosa.feature.mfcc(audio, sr=fs, n_mfcc=n_coefs).T
        #Stack de la base de datos con los mfcc calculados
        base = np.vstack((base,mfcc_raw))
    
    return base[1:] #El primero no lo devolvemos porqué son los ceros de inializacion

# %%
def read_mfcc(path):
    ''' Reads mfcc file from person
        Parametros:
        - path: path donde leer el mfcc
    '''
    mfcc = np.loadtxt(path, delimiter=',')
    
    return mfcc

# %%
def verification_list(speecon):
    ''' Crea listas para calcular los parámetros posteriormente
        Estructura listas:
        - Hablantes entrenamiento (37.5%) : Son los audios que usamos para 
        entrenar el modelo GMM
        - Hablantes testing (12.5%) : Son unos audios de las personas de entrenamiento
        reservados para testing
        - Impostores (50%): Son las personas que no pertenecen al sistema
        Funcionamiento:
        - Partimos el dataset en dos partes, personas correctas y personas incorrectas(impostores)
        - Las personas correctas las partimos en 3/4 para entrenamiento y 1/4 parte testing
        - Guardamos el path hacia los ficheros en listas
    '''
    #Diccionario para contener los datos
    training = list()
    testing_good = list()
    impostor = list()
    #count = 0
    
    # Iteramos la base de datos de speecon primero bloque a bloque 
    # y luego persona a persona
    for block in os.listdir(speecon):
        block_path = os.path.join(speecon,block)
        
        # Listamos todos los ficheros en el Block
        ses_block = os.listdir(block_path)
        # Los desordenamos
        random.shuffle(ses_block)
        
        s = len(ses_block)
        
        # Y escojemos la mitad como usuarios buenos y la mitad como impostores
        # (Usamos floor division para obtener numeros pares)
        legit_users = ses_block[:s//2]
        impostors = ses_block[s//2:(s//2)*2]
        
        
        for user in legit_users:
            ses_path = os.path.join(block_path,user)
            
            # Obtenemos los ficheros de la persona
            all_files = glob.glob(f"{ses_path}/*.wav")
            
            # Para los users escojemos los 15 primeros ficheros (3/4) para training
            # y los ultimos 5 (1/4) para testing.
            train_files = all_files[:15]
            test_files = all_files[-5:]
            
            # Añadimos a la base de datos
            training.append(train_files)   #En los training es imortante tener una lista para cada hablante
            testing_good.extend(test_files)
        
        for imp in impostors:
            
            # Path
            ses_path = os.path.join(block_path,imp)
            
            # Para los impostores cojemos todos los ficheros para
            # testing
            all_files = glob.glob(f"{ses_path}/*.wav")
            
            # Extendemos la lista
            impostor.extend(all_files)
            
    # Devolvemos una lista con las tres listas         
    return [training, testing_good, impostor]

# %%
def compute_mfccs(lists, n_coefs, train_path, test_good_path, test_bad_path):
    ''' MFCCs Calculation
        Calcula los MFCCs dadas unas listas con los paths a los ficheros de cada tipo
        Parametros:
        - lists: Lista con las tres listas de ficheros
        - n_coefs: numero de coeficientes para calcular los mfccs
        - train_path: Path donde guardar los ficheros de entrenamiento
        - test_good_path: Path donde guardar los ficheros de testeo buenos
        - test_bad_path: Path donde guardar los ficheros de testeo malos (impostores)
    '''  
    
    # Comprovamos que las carpetas existan y si no las creamos
    os.makedirs(train_path, exist_ok=True)
    os.makedirs(test_bad_path, exist_ok=True)
    os.makedirs(test_bad_path, exist_ok=True)
    
    training = lists[0]
    testing_good = lists[1]
    testing = lists[2]
    
    for path_list in training:
        # Para calcular el modelo de la persona usamos todos los
        # audios de train
        train_mfcc = mfcc(path_list,n_coefs)
        
        # Extraemos el nombre de la persona a partir de la path
        person = path_list[0][-10:-7]
        
        # Exportamos a csv
        save_path = os.path.join(train_path, person+'.mfcc')
        np.savetxt(save_path, train_mfcc, delimiter=",")
    
    print("Training MFCC calculated")
    
    i = 0
    for path in testing_good:
        # Extraemos el nombre de la persona a partir de la path
        person = path[-10:-7]
        
        # Creamos una carpeta para cada persona con sus audios,
        # lo hacemos así para despues facilitar su validacion
        os.makedirs(os.path.join(test_good_path, person), exist_ok=True)
        save_path = os.path.join(test_good_path, person, f'audio{i}.mfcc')
        
        # Counter
        i = i+1

        # Calculo de los mfcc
        test_mfcc = mfcc([path],n_coefs)
        
        # Exportamos a csv
        np.savetxt(save_path, test_mfcc, delimiter=",")
        
    print("Good testing MFCC calculated")
       
    i = 0
    for path in testing:
        # Extraemos el nombre de la persona a partir de la path
        person = path[-10:-7]
        
        # Creamos una carpeta para cada persona con sus audios
        os.makedirs(os.path.join(test_bad_path, person), exist_ok=True)
        save_path = os.path.join(test_bad_path, person, f'audio{i}.mfcc')

        # Counter
        i = i+1
        
        # Calculo de los mfcc
        test_mfcc = mfcc([path],n_coefs)
        
        #Exportamos a csv
        np.savetxt(save_path, test_mfcc, delimiter=",")
        
    print("Impostor MFCC calculated")

# %%
def train_gmm(n_gmms,train_path):
    ''' Entrenamiento de las GMM
        Parametros:
        - n_gmms: Numero de coeficientes a usar para calcular el modelo GMM
        - train_path: Path para leer los ficheros .csv con las MFCCs
        Devuelve:
        - trained_gmm: diccionario con los nombres y las GMMs
    '''
    # Lectura de los ficheros en la train_path
    files_train = glob.glob(f"{train_path}/*.mfcc")
    
    trained_gmm = dict()
    
    for mfcc_path in files_train:
        # Leemos los MFCCs para esa persona
        mfcc = read_mfcc(mfcc_path)
        
        # Calculo de la GMM
        gmm=GMM(n_gmms, n_init=2).fit(mfcc) 
        
        # Extracción del nombre a partir del path
        person = mfcc_path[-8:-5]
        
        # Guardamos gmm en el diccionario
        trained_gmm[person] = gmm
        
    return trained_gmm

# %%
def train_world_gmm(train_path, n_mfccs, n_gmms):
    base = np.zeros((1,n_mfccs))
    
    files_train = glob.glob(f"{train_path}/*.mfcc")

    for mfcc_path in files_train:
        mfcc = read_mfcc(mfcc_path)
        #Stack de la base de datos con los mfcc calculados
        base = np.vstack((base,mfcc))

    gmm=GMM(n_gmms, n_init=2).fit(base)
    
    return gmm

# %%
def verification(trained_gmm, test_bad_path, test_good_path, world_gmm):
    ''' Verification del locutor
        Para cada hablante (una gmm por hablante) calcula la probabilidad de que 
        un conjunto de audios pertenezca a la persona. Para ese conjunto de audios
        se escojen 5 audios que pertenecen a la persona y 5 que no.
        Parametros:
        - trained_gmm: diccionario con la gmm de cada persona
        - test_bad_path: path donde encontrar los ficheros de testing malos (impostores)
        - test_good_path: path donde encontrar los ficheros de testing buenos
        Devuelve:
        - assigned: diccionario con una lista de las scores de cada audio
        las 5 primeras scores corresponden a audios de la gmm y los 5 siguientes no
    '''
    
    # Contenedor de datos
    assigned = dict()
    
    # Todos los ficheros impostores
    all_test =  glob.glob(f"{test_bad_path}/*/*.mfcc")
    # Shuffle para desordenar los ficheros y que salgan variados
    random.shuffle(all_test)
        
    # Iteramos el diccionario. key = 'persona' gmm = gmm de la persona
    for key, gmm in trained_gmm.items():
        # Obtenemos los ficheros que corresponden
        good_files = glob.glob(f"{test_good_path}/{key}/*.mfcc")
        # Cojemos 5 ficheros de testing malos (impostores),
        # como estan desordenados nos saldran ficheros de
        # personas distintas
        test_files = [all_test.pop() for i in range(0,5)]
        
        # Sanity check para comprobar que la carpeta no esta vacía
        if len(good_files)==0: continue
        
        # Lista para guardar los datos
        current_gmm = list()
        
        for path in good_files:
            # Leemos mfcc
            read = read_mfcc(path)
            # Extraemos nombre de la persona a partir del path
            person = path[42:45]
            # Calculamos la score (logscore)
            score = gmm.score(read)- world_gmm.score(read)
            # Guardamos en el contenedor
            current_gmm.append(score)
        
        for path in test_files:
            # Leemos mfcc
            read = read_mfcc(path)
            # Extraemos nombre de la persona a partir del path
            person = path[41:44]
            # Calculamos la score (logscore)
            score = gmm.score(read) - world_gmm.score(read)
            # Guardamos en el contenedor
            current_gmm.append(score)
                
        # Guardamos en el contenedor de datos
        assigned[key] = current_gmm

    return assigned

# %%
def compute_threshold(threshold, verification_dict):
    ''' Calculo de las métricas para un determinado threshold
        Parametros:
        - threshold: valor del threshold
        - verificatoin_dict: contenedor de resultados de la funcion
        verification
    '''
    # Variables
    missed = 0
    false_positive = 0
    count = 0
    
    # Iteramos todas las personas
    for key,value in verification_dict.items():
        i = 0
        # Y por todos las scores
        for l in value:
            # Como los 5 primeros son buenos, miramos si es inferior
            # al threshold. En caso afirmativo se comptabiliza como missed
            if l<threshold and i<5: missed += 1
                
            # En los 5 segundos son impostores, miramos si superan el 
            # threshold. En caso afirmativo se comptabiliza como falso positivo
            if l>threshold and i>5: false_positive += 1   
            
            # Counter de operaciones    
            i = i + 1
        
        # Cuenta total de operaciones
        count = count + i
    
    # Calculo del coste
    cost = missed + false_positive*99
    
    # Presentación de resultados
    print(f'TH: {threshold:.2f} | Missed: {missed:3}/{count} | False Positive: {false_positive:3}/{count} | Cost: {cost}')
    
    return cost

# %%
def find_threshold(verification_dict, starting_thr=-80, ending_thr=-50, step_thr=0.2):
    ''' Busqueda de threshold óptimo
        Calcula el threshold con el que conseguimos mejor coste.
        Definimos coste como = missed + 99*false_positive
        Parametros:
        - verification_dict: diccionario devuelto por la funcion verification()
        - starting_thr: Valor inicial de los thresholds evaluados
        - ending_thr: Valor final de los threshold evaluados
        - step_thr: Valor del step de los thresholds
        Devuelve:
        - thr: el mejor threshold para el modelo
    '''
    
    # Constantes de análisis
    cost_min = None
    thr = None
    
    # Abanico de thresholds que vamos a probar
    thr_array = np.arange(starting_thr, ending_thr, step_thr)
    
    # Iteramos todos los thresholds de thr_array
    for threshold in thr_array:
        # Usamos compute_threshold para calcular el coste del threshold
        cost = compute_threshold(threshold, verification_dict)
        
        # Miramos si el coste baja con este thr, en caso afirmativo
        # guardamos los datos
        if cost_min == None or cost_min>cost:
            cost_min = cost
            thr = threshold
        
    # Resultados finales
    print('\nFinal results:')
    compute_threshold(thr, v)
            
    return thr

# %%
# Definimos paths donde exportar los ficheros de las MFCCs
train_path = os.path.join(temp_path,'ver','train')
test_good_path = os.path.join(temp_path,'ver','test_good')
test_bad_path = os.path.join(temp_path,'ver','test_bad')

# %%
lists = verification_list(speecon_path)

# %%
compute_mfccs(lists, 16, train_path, test_good_path, test_bad_path)
# Out:
# Training MFCC calculated
# Good testing MFCC calculated
# Impostor MFCC calculated

# %%
world_gmm = train_world_gmm(train_path, n_mfccs=16, n_gmms=12)

# %%
trained_gmm = train_gmm(n_gmms = 6, train_path = train_path)

# %%
# Si lanza error se tienen que recalcular los MFCCs
v = verification(trained_gmm, test_bad_path, test_good_path, world_gmm)

# %%
thr = find_threshold(v,-50,20,0.2)
# Out:
# TH: -50.00 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -49.80 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -49.60 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -49.40 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -49.20 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -49.00 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -48.80 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -48.60 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -48.40 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -48.20 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -48.00 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -47.80 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -47.60 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -47.40 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -47.20 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -47.00 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -46.80 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -46.60 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -46.40 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -46.20 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -46.00 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -45.80 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -45.60 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -45.40 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -45.20 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -45.00 | Missed:   0/740 | False Positive: 294/740 | Cost: 29106
# TH: -44.80 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -44.60 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -44.40 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -44.20 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -44.00 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -43.80 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -43.60 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -43.40 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -43.20 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -43.00 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -42.80 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -42.60 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -42.40 | Missed:   0/740 | False Positive: 293/740 | Cost: 29007
# TH: -42.20 | Missed:   0/740 | False Positive: 292/740 | Cost: 28908
# TH: -42.00 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -41.80 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -41.60 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -41.40 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -41.20 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -41.00 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -40.80 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -40.60 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -40.40 | Missed:   0/740 | False Positive: 291/740 | Cost: 28809
# TH: -40.20 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -40.00 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -39.80 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -39.60 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -39.40 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -39.20 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -39.00 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -38.80 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -38.60 | Missed:   0/740 | False Positive: 290/740 | Cost: 28710
# TH: -38.40 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -38.20 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -38.00 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -37.80 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -37.60 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -37.40 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -37.20 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -37.00 | Missed:   0/740 | False Positive: 289/740 | Cost: 28611
# TH: -36.80 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -36.60 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -36.40 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -36.20 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -36.00 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -35.80 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -35.60 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -35.40 | Missed:   0/740 | False Positive: 287/740 | Cost: 28413
# TH: -35.20 | Missed:   0/740 | False Positive: 286/740 | Cost: 28314
# TH: -35.00 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -34.80 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -34.60 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -34.40 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -34.20 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -34.00 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -33.80 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -33.60 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -33.40 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -33.20 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -33.00 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -32.80 | Missed:   0/740 | False Positive: 285/740 | Cost: 28215
# TH: -32.60 | Missed:   0/740 | False Positive: 284/740 | Cost: 28116
# TH: -32.40 | Missed:   0/740 | False Positive: 282/740 | Cost: 27918
# TH: -32.20 | Missed:   0/740 | False Positive: 282/740 | Cost: 27918
# TH: -32.00 | Missed:   0/740 | False Positive: 282/740 | Cost: 27918
# TH: -31.80 | Missed:   0/740 | False Positive: 281/740 | Cost: 27819
# TH: -31.60 | Missed:   0/740 | False Positive: 281/740 | Cost: 27819
# TH: -31.40 | Missed:   0/740 | False Positive: 280/740 | Cost: 27720
# TH: -31.20 | Missed:   0/740 | False Positive: 279/740 | Cost: 27621
# TH: -31.00 | Missed:   0/740 | False Positive: 278/740 | Cost: 27522
# TH: -30.80 | Missed:   0/740 | False Positive: 278/740 | Cost: 27522
# TH: -30.60 | Missed:   0/740 | False Positive: 278/740 | Cost: 27522
# TH: -30.40 | Missed:   0/740 | False Positive: 278/740 | Cost: 27522
# TH: -30.20 | Missed:   0/740 | False Positive: 276/740 | Cost: 27324
# TH: -30.00 | Missed:   0/740 | False Positive: 276/740 | Cost: 27324
# TH: -29.80 | Missed:   0/740 | False Positive: 275/740 | Cost: 27225
# TH: -29.60 | Missed:   0/740 | False Positive: 275/740 | Cost: 27225
# TH: -29.40 | Missed:   0/740 | False Positive: 275/740 | Cost: 27225
# TH: -29.20 | Missed:   0/740 | False Positive: 275/740 | Cost: 27225
# TH: -29.00 | Missed:   0/740 | False Positive: 274/740 | Cost: 27126
# TH: -28.80 | Missed:   0/740 | False Positive: 274/740 | Cost: 27126
# TH: -28.60 | Missed:   0/740 | False Positive: 274/740 | Cost: 27126
# TH: -28.40 | Missed:   0/740 | False Positive: 273/740 | Cost: 27027
# TH: -28.20 | Missed:   0/740 | False Positive: 273/740 | Cost: 27027
# TH: -28.00 | Missed:   0/740 | False Positive: 273/740 | Cost: 27027
# TH: -27.80 | Missed:   0/740 | False Positive: 273/740 | Cost: 27027
# TH: -27.60 | Missed:   0/740 | False Positive: 272/740 | Cost: 26928
# TH: -27.40 | Missed:   0/740 | False Positive: 272/740 | Cost: 26928
# TH: -27.20 | Missed:   0/740 | False Positive: 272/740 | Cost: 26928
# TH: -27.00 | Missed:   0/740 | False Positive: 272/740 | Cost: 26928
# TH: -26.80 | Missed:   0/740 | False Positive: 272/740 | Cost: 26928
# TH: -26.60 | Missed:   0/740 | False Positive: 270/740 | Cost: 26730
# TH: -26.40 | Missed:   0/740 | False Positive: 269/740 | Cost: 26631
# TH: -26.20 | Missed:   0/740 | False Positive: 269/740 | Cost: 26631
# TH: -26.00 | Missed:   0/740 | False Positive: 268/740 | Cost: 26532
# TH: -25.80 | Missed:   0/740 | False Positive: 268/740 | Cost: 26532
# TH: -25.60 | Missed:   0/740 | False Positive: 268/740 | Cost: 26532
# TH: -25.40 | Missed:   0/740 | False Positive: 268/740 | Cost: 26532
# TH: -25.20 | Missed:   0/740 | False Positive: 266/740 | Cost: 26334
# TH: -25.00 | Missed:   0/740 | False Positive: 263/740 | Cost: 26037
# TH: -24.80 | Missed:   0/740 | False Positive: 262/740 | Cost: 25938
# TH: -24.60 | Missed:   0/740 | False Positive: 261/740 | Cost: 25839
# TH: -24.40 | Missed:   0/740 | False Positive: 261/740 | Cost: 25839
# TH: -24.20 | Missed:   0/740 | False Positive: 260/740 | Cost: 25740
# TH: -24.00 | Missed:   0/740 | False Positive: 260/740 | Cost: 25740
# TH: -23.80 | Missed:   0/740 | False Positive: 259/740 | Cost: 25641
# TH: -23.60 | Missed:   0/740 | False Positive: 258/740 | Cost: 25542
# TH: -23.40 | Missed:   0/740 | False Positive: 258/740 | Cost: 25542
# TH: -23.20 | Missed:   0/740 | False Positive: 258/740 | Cost: 25542
# TH: -23.00 | Missed:   0/740 | False Positive: 255/740 | Cost: 25245
# TH: -22.80 | Missed:   0/740 | False Positive: 254/740 | Cost: 25146
# TH: -22.60 | Missed:   0/740 | False Positive: 253/740 | Cost: 25047
# TH: -22.40 | Missed:   0/740 | False Positive: 253/740 | Cost: 25047
# TH: -22.20 | Missed:   0/740 | False Positive: 253/740 | Cost: 25047
# TH: -22.00 | Missed:   0/740 | False Positive: 253/740 | Cost: 25047
# TH: -21.80 | Missed:   0/740 | False Positive: 251/740 | Cost: 24849
# TH: -21.60 | Missed:   0/740 | False Positive: 250/740 | Cost: 24750
# TH: -21.40 | Missed:   0/740 | False Positive: 248/740 | Cost: 24552
# TH: -21.20 | Missed:   0/740 | False Positive: 248/740 | Cost: 24552
# TH: -21.00 | Missed:   0/740 | False Positive: 247/740 | Cost: 24453
# TH: -20.80 | Missed:   0/740 | False Positive: 247/740 | Cost: 24453
# TH: -20.60 | Missed:   0/740 | False Positive: 246/740 | Cost: 24354
# TH: -20.40 | Missed:   0/740 | False Positive: 246/740 | Cost: 24354
# TH: -20.20 | Missed:   0/740 | False Positive: 246/740 | Cost: 24354
# TH: -20.00 | Missed:   0/740 | False Positive: 245/740 | Cost: 24255
# TH: -19.80 | Missed:   0/740 | False Positive: 243/740 | Cost: 24057
# TH: -19.60 | Missed:   0/740 | False Positive: 241/740 | Cost: 23859
# TH: -19.40 | Missed:   0/740 | False Positive: 240/740 | Cost: 23760
# TH: -19.20 | Missed:   0/740 | False Positive: 240/740 | Cost: 23760
# TH: -19.00 | Missed:   0/740 | False Positive: 240/740 | Cost: 23760
# TH: -18.80 | Missed:   0/740 | False Positive: 239/740 | Cost: 23661
# TH: -18.60 | Missed:   0/740 | False Positive: 238/740 | Cost: 23562
# TH: -18.40 | Missed:   0/740 | False Positive: 236/740 | Cost: 23364
# TH: -18.20 | Missed:   0/740 | False Positive: 234/740 | Cost: 23166
# TH: -18.00 | Missed:   0/740 | False Positive: 234/740 | Cost: 23166
# TH: -17.80 | Missed:   0/740 | False Positive: 231/740 | Cost: 22869
# TH: -17.60 | Missed:   0/740 | False Positive: 229/740 | Cost: 22671
# TH: -17.40 | Missed:   0/740 | False Positive: 228/740 | Cost: 22572
# TH: -17.20 | Missed:   0/740 | False Positive: 226/740 | Cost: 22374
# TH: -17.00 | Missed:   0/740 | False Positive: 223/740 | Cost: 22077
# TH: -16.80 | Missed:   0/740 | False Positive: 221/740 | Cost: 21879
# TH: -16.60 | Missed:   0/740 | False Positive: 220/740 | Cost: 21780
# TH: -16.40 | Missed:   0/740 | False Positive: 219/740 | Cost: 21681
# TH: -16.20 | Missed:   0/740 | False Positive: 217/740 | Cost: 21483
# TH: -16.00 | Missed:   0/740 | False Positive: 215/740 | Cost: 21285
# TH: -15.80 | Missed:   0/740 | False Positive: 210/740 | Cost: 20790
# TH: -15.60 | Missed:   0/740 | False Positive: 209/740 | Cost: 20691
# TH: -15.40 | Missed:   0/740 | False Positive: 205/740 | Cost: 20295
# TH: -15.20 | Missed:   0/740 | False Positive: 204/740 | Cost: 20196
# TH: -15.00 | Missed:   0/740 | False Positive: 198/740 | Cost: 19602
# TH: -14.80 | Missed:   0/740 | False Positive: 196/740 | Cost: 19404
# TH: -14.60 | Missed:   0/740 | False Positive: 192/740 | Cost: 19008
# TH: -14.40 | Missed:   0/740 | False Positive: 189/740 | Cost: 18711
# TH: -14.20 | Missed:   0/740 | False Positive: 187/740 | Cost: 18513
# TH: -14.00 | Missed:   0/740 | False Positive: 186/740 | Cost: 18414
# TH: -13.80 | Missed:   0/740 | False Positive: 185/740 | Cost: 18315
# TH: -13.60 | Missed:   0/740 | False Positive: 182/740 | Cost: 18018
# TH: -13.40 | Missed:   0/740 | False Positive: 177/740 | Cost: 17523
# TH: -13.20 | Missed:   0/740 | False Positive: 174/740 | Cost: 17226
# TH: -13.00 | Missed:   0/740 | False Positive: 171/740 | Cost: 16929
# TH: -12.80 | Missed:   0/740 | False Positive: 165/740 | Cost: 16335
# TH: -12.60 | Missed:   0/740 | False Positive: 159/740 | Cost: 15741
# TH: -12.40 | Missed:   0/740 | False Positive: 157/740 | Cost: 15543
# TH: -12.20 | Missed:   0/740 | False Positive: 154/740 | Cost: 15246
# TH: -12.00 | Missed:   0/740 | False Positive: 150/740 | Cost: 14850
# TH: -11.80 | Missed:   0/740 | False Positive: 150/740 | Cost: 14850
# TH: -11.60 | Missed:   0/740 | False Positive: 145/740 | Cost: 14355
# TH: -11.40 | Missed:   0/740 | False Positive: 143/740 | Cost: 14157
# TH: -11.20 | Missed:   0/740 | False Positive: 140/740 | Cost: 13860
# TH: -11.00 | Missed:   0/740 | False Positive: 137/740 | Cost: 13563
# TH: -10.80 | Missed:   0/740 | False Positive: 135/740 | Cost: 13365
# TH: -10.60 | Missed:   0/740 | False Positive: 133/740 | Cost: 13167
# TH: -10.40 | Missed:   0/740 | False Positive: 129/740 | Cost: 12771
# TH: -10.20 | Missed:   0/740 | False Positive: 125/740 | Cost: 12375
# TH: -10.00 | Missed:   0/740 | False Positive: 120/740 | Cost: 11880
# TH: -9.80 | Missed:   0/740 | False Positive: 117/740 | Cost: 11583
# TH: -9.60 | Missed:   0/740 | False Positive: 109/740 | Cost: 10791
# TH: -9.40 | Missed:   0/740 | False Positive: 107/740 | Cost: 10593
# TH: -9.20 | Missed:   0/740 | False Positive: 103/740 | Cost: 10197
# TH: -9.00 | Missed:   0/740 | False Positive:  99/740 | Cost: 9801
# TH: -8.80 | Missed:   0/740 | False Positive:  93/740 | Cost: 9207
# TH: -8.60 | Missed:   0/740 | False Positive:  90/740 | Cost: 8910
# TH: -8.40 | Missed:   0/740 | False Positive:  87/740 | Cost: 8613
# TH: -8.20 | Missed:   0/740 | False Positive:  82/740 | Cost: 8118
# TH: -8.00 | Missed:   0/740 | False Positive:  78/740 | Cost: 7722
# TH: -7.80 | Missed:   0/740 | False Positive:  77/740 | Cost: 7623
# TH: -7.60 | Missed:   0/740 | False Positive:  72/740 | Cost: 7128
# TH: -7.40 | Missed:   1/740 | False Positive:  71/740 | Cost: 7030
# TH: -7.20 | Missed:   1/740 | False Positive:  67/740 | Cost: 6634
# TH: -7.00 | Missed:   1/740 | False Positive:  64/740 | Cost: 6337
# TH: -6.80 | Missed:   1/740 | False Positive:  64/740 | Cost: 6337
# TH: -6.60 | Missed:   1/740 | False Positive:  59/740 | Cost: 5842
# TH: -6.40 | Missed:   1/740 | False Positive:  57/740 | Cost: 5644
# TH: -6.20 | Missed:   1/740 | False Positive:  51/740 | Cost: 5050
# TH: -6.00 | Missed:   1/740 | False Positive:  50/740 | Cost: 4951
# TH: -5.80 | Missed:   1/740 | False Positive:  47/740 | Cost: 4654
# TH: -5.60 | Missed:   3/740 | False Positive:  41/740 | Cost: 4062
# TH: -5.40 | Missed:   3/740 | False Positive:  35/740 | Cost: 3468
# TH: -5.20 | Missed:   3/740 | False Positive:  31/740 | Cost: 3072
# TH: -5.00 | Missed:   3/740 | False Positive:  28/740 | Cost: 2775
# TH: -4.80 | Missed:   3/740 | False Positive:  23/740 | Cost: 2280
# TH: -4.60 | Missed:   3/740 | False Positive:  20/740 | Cost: 1983
# TH: -4.40 | Missed:   3/740 | False Positive:  18/740 | Cost: 1785
# TH: -4.20 | Missed:   3/740 | False Positive:  14/740 | Cost: 1389
# TH: -4.00 | Missed:   4/740 | False Positive:  14/740 | Cost: 1390
# TH: -3.80 | Missed:   4/740 | False Positive:  10/740 | Cost: 994
# TH: -3.60 | Missed:   4/740 | False Positive:   9/740 | Cost: 895
# TH: -3.40 | Missed:   4/740 | False Positive:   6/740 | Cost: 598
# TH: -3.20 | Missed:   4/740 | False Positive:   6/740 | Cost: 598
# TH: -3.00 | Missed:   4/740 | False Positive:   5/740 | Cost: 499
# TH: -2.80 | Missed:   4/740 | False Positive:   4/740 | Cost: 400
# TH: -2.60 | Missed:   4/740 | False Positive:   4/740 | Cost: 400
# TH: -2.40 | Missed:   6/740 | False Positive:   4/740 | Cost: 402
# TH: -2.20 | Missed:   7/740 | False Positive:   3/740 | Cost: 304
# TH: -2.00 | Missed:   9/740 | False Positive:   3/740 | Cost: 306
# TH: -1.80 | Missed:   9/740 | False Positive:   1/740 | Cost: 108
# TH: -1.60 | Missed:  13/740 | False Positive:   1/740 | Cost: 112
# TH: -1.40 | Missed:  18/740 | False Positive:   0/740 | Cost: 18
# TH: -1.20 | Missed:  21/740 | False Positive:   0/740 | Cost: 21
# TH: -1.00 | Missed:  27/740 | False Positive:   0/740 | Cost: 27
# TH: -0.80 | Missed:  32/740 | False Positive:   0/740 | Cost: 32
# TH: -0.60 | Missed:  37/740 | False Positive:   0/740 | Cost: 37
# TH: -0.40 | Missed:  47/740 | False Positive:   0/740 | Cost: 47
# TH: -0.20 | Missed:  56/740 | False Positive:   0/740 | Cost: 56
# TH: 0.00 | Missed:  63/740 | False Positive:   0/740 | Cost: 63
# TH: 0.20 | Missed:  75/740 | False Positive:   0/740 | Cost: 75
# TH: 0.40 | Missed:  89/740 | False Positive:   0/740 | Cost: 89
# TH: 0.60 | Missed: 104/740 | False Positive:   0/740 | Cost: 104
# TH: 0.80 | Missed: 122/740 | False Positive:   0/740 | Cost: 122
# TH: 1.00 | Missed: 135/740 | False Positive:   0/740 | Cost: 135
# TH: 1.20 | Missed: 152/740 | False Positive:   0/740 | Cost: 152
# TH: 1.40 | Missed: 183/740 | False Positive:   0/740 | Cost: 183
# TH: 1.60 | Missed: 208/740 | False Positive:   0/740 | Cost: 208
# TH: 1.80 | Missed: 234/740 | False Positive:   0/740 | Cost: 234
# TH: 2.00 | Missed: 254/740 | False Positive:   0/740 | Cost: 254
# TH: 2.20 | Missed: 273/740 | False Positive:   0/740 | Cost: 273
# TH: 2.40 | Missed: 293/740 | False Positive:   0/740 | Cost: 293
# TH: 2.60 | Missed: 307/740 | False Positive:   0/740 | Cost: 307
# TH: 2.80 | Missed: 316/740 | False Positive:   0/740 | Cost: 316
# TH: 3.00 | Missed: 320/740 | False Positive:   0/740 | Cost: 320
# TH: 3.20 | Missed: 325/740 | False Positive:   0/740 | Cost: 325
# TH: 3.40 | Missed: 334/740 | False Positive:   0/740 | Cost: 334
# TH: 3.60 | Missed: 340/740 | False Positive:   0/740 | Cost: 340
# TH: 3.80 | Missed: 346/740 | False Positive:   0/740 | Cost: 346
# TH: 4.00 | Missed: 352/740 | False Positive:   0/740 | Cost: 352
# TH: 4.20 | Missed: 356/740 | False Positive:   0/740 | Cost: 356
# TH: 4.40 | Missed: 358/740 | False Positive:   0/740 | Cost: 358
# TH: 4.60 | Missed: 358/740 | False Positive:   0/740 | Cost: 358
# TH: 4.80 | Missed: 360/740 | False Positive:   0/740 | Cost: 360
# TH: 5.00 | Missed: 360/740 | False Positive:   0/740 | Cost: 360
# TH: 5.20 | Missed: 361/740 | False Positive:   0/740 | Cost: 361
# TH: 5.40 | Missed: 365/740 | False Positive:   0/740 | Cost: 365
# TH: 5.60 | Missed: 367/740 | False Positive:   0/740 | Cost: 367
# TH: 5.80 | Missed: 368/740 | False Positive:   0/740 | Cost: 368
# TH: 6.00 | Missed: 369/740 | False Positive:   0/740 | Cost: 369
# TH: 6.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 6.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 6.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 6.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 7.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 7.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 7.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 7.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 7.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 8.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 8.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 8.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 8.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 8.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 9.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 9.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 9.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 9.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 9.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 10.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 10.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 10.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 10.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 10.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 11.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 11.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 11.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 11.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 11.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 12.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 12.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 12.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 12.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 12.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 13.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 13.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 13.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 13.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 13.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 14.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 14.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 14.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 14.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 14.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 15.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 15.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 15.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 15.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 15.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 16.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 16.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 16.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 16.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 16.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 17.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 17.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 17.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 17.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 17.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 18.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 18.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 18.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 18.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 18.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 19.00 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 19.20 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 19.40 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 19.60 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
# TH: 19.80 | Missed: 370/740 | False Positive:   0/740 | Cost: 370
#
# Final results:
# TH: -1.40 | Missed:  18/740 | False Positive:   0/740 | Cost: 18
