# %% [markdown]
# # Plot de col2 i col3

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
col1 = np.loadtxt('./exports/col2.txt')
col2 = np.loadtxt('./exports/col3.txt')

# %%
plt.scatter(col1,col2, alpha=0.5, s=0.7)

# %% [markdown]
# # Càrrega de fitxers i plot columna  columna

# %%
#LOAD DATA
data = list()
for i in range(1,9):
    data.append(np.loadtxt(f'./exports/col{i}.txt'))

# %%
#CREATE PLOTS
fig = plt.figure(figsize=(20, 20))
for i in range(0,8):
    for j in range(0,8):
        ax = fig.add_subplot(9,9,i*9+j+1)
        ax.scatter(data[i], data[j],alpha=0.8, s=0.7)
#fig.suptitle('Distributions of Iris Features')
plt.show()

# %%
for i in range(0,9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
data[7]
# Out:
# array([-0.204017  , -0.0875611 ,  0.19114   , ...,  0.0135867 ,
#        -0.154797  , -0.00937689])
